# %% [markdown]
# ## Carrie Little
# ## SIPRI Milex Data - Data Cleaning 1

# %% [markdown]
# ### View Excel Sheets included in file

# %%
import pandas as pd

# Load data file
file_path = 'SIPRI-Milex-data-1948-2023.xlsx'

# Check the sheet names in the Excel file
excel_file = pd.ExcelFile(file_path)
excel_file.sheet_names
# Out:
# ['Front page',
#  'Regional totals',
#  'Local currency financial years',
#  'Local currency calendar years',
#  'Constant (2022) US$',
#  'Current US$',
#  'Share of GDP',
#  'Per capita',
#  'Share of Govt. spending',
#  'Footnotes']

# %% [markdown]
# ### Will Load, Clean, and Export to CSV the following sheets:
# #### 1. 'Constant (2022) US$'
# #### 2. 'Share of GDP'
# #### 3. 'Per capita'
# #### 4. 'Share of Govt. spending'

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 1. Load and Clean 'Constant (2022) US$' Sheet

# %%
# Load sheet
data_constant_usd = pd.read_excel(file_path, sheet_name="Constant (2022) US$")

# Display the first 10 rows
data_constant_usd.head(10)
# Out:
#   Military expenditure by country, in constant (2022) US$ m., 1948-2023      © SIPRI 2023  \
# 0  Figures are in US $m., at constant 2022 prices...
# 1  Figures in blue are SIPRI estimates. Figures i...
# 2  ". ." = data unavailable. "xxx" = country did ...
# 3                                                NaN
# 4                                            Country
# 5                                                NaN
# 6                                             Africa
# 7                                       North Africa
# 8                                            Algeria
# 9                                              Libya
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN      Notes       1948       1949       1950       1951
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN          §        ...        ...        ...        ...
# 9         NaN        ‡§¶        ...        ...        ...        ...
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ...   Unnamed: 69   Unnamed: 70  \
# 0        NaN        NaN        NaN  ...           NaN           NaN
# 1        NaN        NaN        NaN  ...           NaN           NaN
# 2        NaN        NaN        NaN  ...           NaN           NaN
# 3        NaN        NaN        NaN  ...           NaN           NaN
# 4       1952       1953       1954  ...          2014          2015
# 5        NaN        NaN        NaN  ...           NaN           NaN
# 6        NaN        NaN        NaN  ...           NaN           NaN
# 7        NaN        NaN        NaN  ...           NaN           NaN
# 8        ...        ...        ...  ...  10098.601351  10565.030238
# 9        ...        ...        ...  ...   3236.511746           ...
#
#     Unnamed: 71  Unnamed: 72  Unnamed: 73   Unnamed: 74   Unnamed: 75  \
# 0           NaN          NaN          NaN           NaN           NaN
# 1           NaN          NaN          NaN           NaN           NaN
# 2           NaN          NaN          NaN           NaN           NaN
# 3           NaN          NaN          NaN           NaN           NaN
# 4          2016         2017         2018          2019          2020
# 5           NaN          NaN          NaN           NaN           NaN
# 6           NaN          NaN          NaN           NaN           NaN
# 7           NaN          NaN          NaN           NaN           NaN
# 8  10596.564106  10035.46938  9624.504002  10383.207823  10141.073361
# 9           ...          ...          ...           ...           ...
#
#    Unnamed: 76  Unnamed: 77  Unnamed: 78
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4         2021         2022         2023
# 5          NaN          NaN          NaN
# 6          NaN          NaN          NaN
# 7          NaN          NaN          NaN
# 8  9455.120355  9145.810174  16052.12907
# 9          ...          ...          ...
#
# [10 rows x 79 columns]

# %%
# Reload and skip irrelevant rows to get only the actual data
data_cleaned_1 = pd.read_excel(file_path, sheet_name="Constant (2022) US$", skiprows=5)

# Adjust year column selection to match the integer format in the dataset
year_columns = list(range(1948, 2024))  # Using integers for years
data_cleaned_1 = data_cleaned_1[['Country'] + year_columns]

# Display the cleaned data to verify structure and ensure it matches expectations for analysis
data_cleaned_1.head(10)
# Out:
#               Country 1948 1949 1950 1951 1952 1953 1954 1955        1956  \
# 0                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 1              Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 2        North Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 3             Algeria  ...  ...  ...  ...  ...  ...  ...  ...         ...
# 4               Libya  ...  ...  ...  ...  ...  ...  ...  ...         ...
# 5             Morocco  ...  ...  ...  ...  ...  ...  ...  ...  111.729459
# 6             Tunisia  ...  ...  ...  ...  ...  ...  ...  ...         ...
# 7  sub-Saharan Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 8              Angola  ...  ...  ...  ...  ...  ...  ...  ...         ...
# 9               Benin  ...  ...  ...  ...  ...  ...  ...  ...         ...
#
#    ...          2014          2015          2016         2017         2018  \
# 0  ...           NaN           NaN           NaN          NaN          NaN
# 1  ...           NaN           NaN           NaN          NaN          NaN
# 2  ...           NaN           NaN           NaN          NaN          NaN
# 3  ...  10098.601351  10565.030238  10596.564106  10035.46938  9624.504002
# 4  ...   3236.511746           ...           ...          ...          ...
# 5  ...   3875.234437   3577.909489   3599.711151   3705.59815  3731.482387
# 6  ...    790.774649    943.413433    1004.52727   932.551601   936.298112
# 7  ...           NaN           NaN           NaN          NaN          NaN
# 8  ...   7085.001136   4170.569003   3331.954433  2882.802335  2376.791945
# 9  ...     79.181623     92.386241     81.738888   115.570255    84.788851
#
#            2019          2020         2021         2022         2023
# 0           NaN           NaN          NaN          NaN          NaN
# 1           NaN           NaN          NaN          NaN          NaN
# 2           NaN           NaN          NaN          NaN          NaN
# 3  10383.207823  10141.073361  9455.120355  9145.810174  16052.12907
# 4           ...           ...          ...          ...          ...
# 5   3809.704239   4883.245061  5026.030416  4995.028074  4868.719082
# 6   1151.413236   1205.706839  1210.355285  1156.186916  1113.466124
# 7           NaN           NaN          NaN          NaN          NaN
# 8   2171.788155   1901.093962  1619.929593  1622.763732  1639.712947
# 9      67.97717     68.326999     87.81903    110.01037   130.522931
#
# [10 rows x 77 columns]

# %%
# Remove rows where 'Country' is NaN or contains placeholders like "Africa", "North Africa", etc.
# Keep rows where 'Country' is a specific country (e.g., not containing NaN or regional labels)

# Drop rows with any NaN values in the 'Country' column
data_cleaned_1 = data_cleaned_1.dropna(subset=['Country'])

# Remove rows where the data in any year column contains placeholders like '...' and convert values to numeric
data_cleaned_1.replace('...', pd.NA, inplace=True)
data_cleaned_1.iloc[:, 1:] = data_cleaned_1.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# Display the cleaned data to confirm it is ready for analysis
data_cleaned_1.head()
# Out:
#         Country 1948 1949 1950 1951 1952 1953 1954 1955        1956  ...  \
# 1        Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN  ...
# 2  North Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN  ...
# 3       Algeria  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN  ...
# 4         Libya  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN  ...
# 5       Morocco  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  111.729459  ...
#
#            2014          2015          2016         2017         2018  \
# 1           NaN           NaN           NaN          NaN          NaN
# 2           NaN           NaN           NaN          NaN          NaN
# 3  10098.601351  10565.030238  10596.564106  10035.46938  9624.504002
# 4   3236.511746           NaN           NaN          NaN          NaN
# 5   3875.234437   3577.909489   3599.711151   3705.59815  3731.482387
#
#            2019          2020         2021         2022         2023
# 1           NaN           NaN          NaN          NaN          NaN
# 2           NaN           NaN          NaN          NaN          NaN
# 3  10383.207823  10141.073361  9455.120355  9145.810174  16052.12907
# 4           NaN           NaN          NaN          NaN          NaN
# 5   3809.704239   4883.245061  5026.030416  4995.028074  4868.719082
#
# [5 rows x 77 columns]

# %%
# Remove regional aggregates by keeping only rows where 'Country' is a specific country
# Here, we can filter out rows with common regional terms or just focus on rows with substantial numeric data

# Filter to keep only rows with at least some non-null values across the years
data_constant_usd = data_cleaned_1.dropna(thresh=5, axis=0).reset_index(drop=True)

# Display the cleaned data focused on individual countries
data_constant_usd.head()
# Out:
#    Country 1948 1949 1950 1951 1952 1953 1954 1955        1956  ...  \
# 0  Algeria  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN  ...
# 1    Libya  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN  ...
# 2  Morocco  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  111.729459  ...
# 3  Tunisia  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN  ...
# 4   Angola  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN  ...
#
#            2014          2015          2016         2017         2018  \
# 0  10098.601351  10565.030238  10596.564106  10035.46938  9624.504002
# 1   3236.511746           NaN           NaN          NaN          NaN
# 2   3875.234437   3577.909489   3599.711151   3705.59815  3731.482387
# 3    790.774649    943.413433    1004.52727   932.551601   936.298112
# 4   7085.001136   4170.569003   3331.954433  2882.802335  2376.791945
#
#            2019          2020         2021         2022         2023
# 0  10383.207823  10141.073361  9455.120355  9145.810174  16052.12907
# 1           NaN           NaN          NaN          NaN          NaN
# 2   3809.704239   4883.245061  5026.030416  4995.028074  4868.719082
# 3   1151.413236   1205.706839  1210.355285  1156.186916  1113.466124
# 4   2171.788155   1901.093962  1619.929593  1622.763732  1639.712947
#
# [5 rows x 77 columns]

# %%
# Output the cleaned DataFrame with country-specific military expenditure data to a CSV file
output_path = "Cleaned_SIPRI_Military_Expenditure-Constant_2022.csv"
data_constant_usd.to_csv(output_path, index=False)

output_path
# Out:
# 'Cleaned_SIPRI_Military_Expenditure-Constant_2022.csv'

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 2. Load and Clean 'Share of GDP' Sheet

# %%
# Load sheet
data_share_GDP = pd.read_excel(file_path, sheet_name="Share of GDP")

# Display the first few rows
data_share_GDP.head(10)
# Out:
#   Military expenditure by country as percentage of gross domestic product, 1948-2023     © SIPRI 2023  \
# 0      Countries are grouped by region and subregion
# 1  Figures in blue are SIPRI estimates. Figures i...
# 2  ". ." = data unavailable. "xxx" = country did ...
# 3                                                NaN
# 4                                            Country
# 5                                                NaN
# 6                                             Africa
# 7                                       North Africa
# 8                                            Algeria
# 9                                              Libya
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4      Notes       1948       1949       1950       1951       1952
# 5        NaN        NaN        NaN        NaN        NaN        NaN
# 6        NaN        NaN        NaN        NaN        NaN        NaN
# 7        NaN        NaN        NaN        NaN        NaN        NaN
# 8          §        ...        ...        ...        ...        ...
# 9        ‡§¶        ...        ...        ...        ...        ...
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 68 Unnamed: 69 Unnamed: 70  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4       1953       1954       1955  ...        2014        2015        2016
# 5        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 6        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 7        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 8        ...        ...        ...  ...    0.055485    0.062702    0.063849
# 9        ...        ...        ...  ...    0.154796         ...         ...
#
#   Unnamed: 71 Unnamed: 72 Unnamed: 73 Unnamed: 74 Unnamed: 75 Unnamed: 76  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4        2017        2018        2019        2020        2021        2022
# 5         NaN         NaN         NaN         NaN         NaN         NaN
# 6         NaN         NaN         NaN         NaN         NaN         NaN
# 7         NaN         NaN         NaN         NaN         NaN         NaN
# 8    0.059244    0.054836    0.059999    0.066587    0.055708     0.04695
# 9         ...         ...         ...         ...         ...         ...
#
#   Unnamed: 77
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4        2023
# 5         NaN
# 6         NaN
# 7         NaN
# 8    0.081717
# 9         ...
#
# [10 rows x 78 columns]

# %%
# Reload and skip irrelevant rows to get only the actual data
data_cleaned_2 = pd.read_excel(file_path, sheet_name="Share of GDP", skiprows=5)

# Adjust year column selection to match the integer format in the dataset
year_columns = list(range(1948, 2024))  # Using integers for years
data_cleaned_2 = data_cleaned_2[['Country'] + year_columns]

# Display the cleaned data to verify structure and ensure it matches expectations for analysis
data_cleaned_2.head(10)
# Out:
#               Country 1948 1949 1950 1951 1952 1953 1954 1955      1956  ...  \
# 0                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 1              Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 2        North Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 3             Algeria  ...  ...  ...  ...  ...  ...  ...  ...       ...  ...
# 4               Libya  ...  ...  ...  ...  ...  ...  ...  ...       ...  ...
# 5             Morocco  ...  ...  ...  ...  ...  ...  ...  ...  0.011807  ...
# 6             Tunisia  ...  ...  ...  ...  ...  ...  ...  ...       ...  ...
# 7  sub-Saharan Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 8              Angola  ...  ...  ...  ...  ...  ...  ...  ...       ...  ...
# 9               Benin  ...  ...  ...  ...  ...  ...  ...  ...       ...  ...
#
#        2014      2015      2016      2017      2018      2019      2020  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3  0.055485  0.062702  0.063849  0.059244  0.054836  0.059999  0.066587
# 4  0.154796       ...       ...       ...       ...       ...       ...
# 5  0.033985    0.0296  0.029821  0.029459  0.029029  0.028658  0.039797
# 6  0.018069  0.021396   0.02225  0.020318  0.019764  0.023833  0.027098
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8  0.046985  0.031054  0.027333   0.02508  0.019558  0.017391   0.01737
# 9  0.007009  0.007985  0.006736  0.009206  0.006329  0.004733  0.004588
#
#        2021      2022      2023
# 0       NaN       NaN       NaN
# 1       NaN       NaN       NaN
# 2       NaN       NaN       NaN
# 3  0.055708   0.04695  0.081717
# 4       ...       ...       ...
# 5  0.037552  0.038146  0.036387
# 6  0.026367  0.024734  0.023579
# 7       NaN       NaN       NaN
# 8   0.01301  0.013168  0.013325
# 9  0.005509  0.006321  0.007112
#
# [10 rows x 77 columns]

# %%
# Remove rows where 'Country' is NaN or contains placeholders like "Africa", "North Africa", etc.
# Keep rows where 'Country' is a specific country (e.g., not containing NaN or regional labels)

# Drop rows with any NaN values in the 'Country' column
data_cleaned_2 = data_cleaned_2.dropna(subset=['Country'])

# Remove rows where the data in any year column contains placeholders like '...' and convert values to numeric
data_cleaned_2.replace('...', pd.NA, inplace=True)
data_cleaned_2.iloc[:, 1:] = data_cleaned_2.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# Display the cleaned data to confirm it is ready for analysis
data_cleaned_2.head(10)
# Out:
#                Country 1948 1949 1950 1951 1952 1953 1954 1955      1956  ...  \
# 1               Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 2         North Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 3              Algeria  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 4                Libya  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 5              Morocco  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  0.011807  ...
# 6              Tunisia  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 7   sub-Saharan Africa  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 8               Angola  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 9                Benin  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
# 10            Botswana  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...
#
#         2014      2015      2016      2017      2018      2019      2020  \
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3   0.055485  0.062702  0.063849  0.059244  0.054836  0.059999  0.066587
# 4   0.154796       NaN       NaN       NaN       NaN       NaN       NaN
# 5   0.033985    0.0296  0.029821  0.029459  0.029029  0.028658  0.039797
# 6   0.018069  0.021396   0.02225  0.020318  0.019764  0.023833  0.027098
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8   0.046985  0.031054  0.027333   0.02508  0.019558  0.017391   0.01737
# 9   0.007009  0.007985  0.006736  0.009206  0.006329  0.004733  0.004588
# 10   0.02212  0.028252  0.034107  0.032486  0.029248  0.030812  0.033348
#
#         2021      2022      2023
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3   0.055708   0.04695  0.081717
# 4        NaN       NaN       NaN
# 5   0.037552  0.038146  0.036387
# 6   0.026367  0.024734  0.023579
# 7        NaN       NaN       NaN
# 8    0.01301  0.013168  0.013325
# 9   0.005509  0.006321  0.007112
# 10  0.030456  0.023821  0.025298
#
# [10 rows x 77 columns]

# %%
# Remove regional aggregates by keeping only rows where 'Country' is a specific country
# Here, we can filter out rows with common regional terms or just focus on rows with substantial numeric data

# Filter to keep only rows with at least some non-null values across the years
data_share_GDP = data_cleaned_2.dropna(thresh=5, axis=0).reset_index(drop=True)

# Display the cleaned data focused on individual countries
data_share_GDP.head()
# Out:
#    Country 1948 1949 1950 1951 1952 1953 1954 1955      1956  ...      2014  \
# 0  Algeria  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...  0.055485
# 1    Libya  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...  0.154796
# 2  Morocco  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  0.011807  ...  0.033985
# 3  Tunisia  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...  0.018069
# 4   Angola  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  ...  0.046985
#
#        2015      2016      2017      2018      2019      2020      2021  \
# 0  0.062702  0.063849  0.059244  0.054836  0.059999  0.066587  0.055708
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2    0.0296  0.029821  0.029459  0.029029  0.028658  0.039797  0.037552
# 3  0.021396   0.02225  0.020318  0.019764  0.023833  0.027098  0.026367
# 4  0.031054  0.027333   0.02508  0.019558  0.017391   0.01737   0.01301
#
#        2022      2023
# 0   0.04695  0.081717
# 1       NaN       NaN
# 2  0.038146  0.036387
# 3  0.024734  0.023579
# 4  0.013168  0.013325
#
# [5 rows x 77 columns]

# %%
# Output the cleaned DataFrame with country-specific military expenditure data to a CSV file
output_path = "Cleaned_SIPRI_Military_Expenditure-Share_of_GDP.csv"
data_share_GDP.to_csv(output_path, index=False)

output_path
# Out:
# 'Cleaned_SIPRI_Military_Expenditure-Share_of_GDP.csv'

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 3. Load and Clean 'Per capita' Sheet

# %%
# Load sheet
data_Per_capita = pd.read_excel(file_path, sheet_name="Per capita")

# Display the first few rows
data_Per_capita.head(10)
# Out:
#   Military expenditure per capita  by country, 1948-2023     © SIPRI 2023  \
# 0                         Figures are in current US$
# 1      Countries are grouped by region and subregion
# 2  Figures in blue are SIPRI estimates. Figures i...
# 3  ". ." = data unavailable. "xxx" = country did ...
# 4                                                NaN
# 5                                            Country
# 6                                             Africa
# 7                                       North Africa
# 8                                            Algeria
# 9                                              Libya
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
# 5      Notes       1988       1989       1990       1991       1992
# 6        NaN        NaN        NaN        NaN        NaN        NaN
# 7        NaN        NaN        NaN        NaN        NaN        NaN
# 8          §  42.429214  34.323059  35.436521  21.623099  39.378707
# 9        ‡§¶        ...        ...        ...        ...        ...
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 5       1993       1994       1995  ...        2014        2015        2016
# 6        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 7        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 8  46.680964  47.782928  43.354702  ...  250.886996  263.326354   253.28049
# 9        ...        ...        ...  ...  615.882666         ...         ...
#
#   Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5        2017        2018        2019        2020        2021        2022
# 6         NaN         NaN         NaN         NaN         NaN         NaN
# 7         NaN         NaN         NaN         NaN         NaN         NaN
# 8  244.873569  228.581208  241.273869   223.42533  206.266945  203.679268
# 9         ...         ...         ...         ...         ...         ...
#
#   Unnamed: 37
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5        2023
# 6         NaN
# 7         NaN
# 8   400.47292
# 9         ...
#
# [10 rows x 38 columns]

# %%
# Reload and skip irrelevant rows to get only the actual data
data_cleaned_3 = pd.read_excel(file_path, sheet_name="Per capita", skiprows=6)

# Adjust year column selection to match the integer format in the dataset
year_columns = list(range(1988, 2024))  # Using integers for years
data_cleaned_3 = data_cleaned_3[['Country'] + year_columns]

# Display the cleaned data to verify structure and ensure it matches expectations for analysis
data_cleaned_3.head(10)
# Out:
#               Country        1988        1989        1990        1991  \
# 0              Africa         NaN         NaN         NaN         NaN
# 1        North Africa         NaN         NaN         NaN         NaN
# 2             Algeria   42.429214   34.323059   35.436521   21.623099
# 3               Libya         ...         ...         ...         ...
# 4             Morocco   38.669076   41.020171   43.535896   45.959889
# 5             Tunisia   28.866073   28.350537   29.366811   30.201905
# 6  sub-Saharan Africa         NaN         NaN         NaN         NaN
# 7              Angola  132.855604  170.343509  148.038985   84.328055
# 8               Benin    7.643127    5.728098    6.393394         ...
# 9            Botswana   74.343453   78.954236  116.518151  124.742352
#
#          1992        1993        1994        1995       1996  ...        2014  \
# 0         NaN         NaN         NaN         NaN        NaN  ...         NaN
# 1         NaN         NaN         NaN         NaN        NaN  ...         NaN
# 2   39.378707   46.680964   47.782928   43.354702  50.109747  ...  250.886996
# 3         ...         ...         ...         ...        ...  ...  615.882666
# 4   48.365283   48.505698   52.104802   54.058374  53.599344  ...  118.211116
# 5   32.906636   30.763856   32.491398   36.895035  42.145002  ...   79.478516
# 6         NaN         NaN         NaN         NaN        NaN  ...         NaN
# 7   62.862251   136.09433   44.197829   16.808778  11.106301  ...  252.368376
# 8         ...         ...         ...         ...        ...  ...    8.760311
# 9  125.254079  126.998278  113.320321  107.431333  88.849643  ...  153.221824
#
#          2015       2016        2017        2018        2019        2020  \
# 0         NaN        NaN         NaN         NaN         NaN         NaN
# 1         NaN        NaN         NaN         NaN         NaN         NaN
# 2  263.326354  253.28049  244.873569  228.581208  241.273869   223.42533
# 3         ...        ...         ...         ...         ...         ...
# 4   94.243465  94.768334   97.429113  102.896263  102.504513  131.673155
# 5   84.729783  84.522908   72.724543   70.747286   83.070971   95.162997
# 6         NaN        NaN         NaN         NaN         NaN         NaN
# 7  128.281396   94.80552  101.389418   63.426928   45.463891   29.723418
# 8     8.31392   7.067635   10.014899    7.554847    5.542098    5.680441
# 9  166.481509  218.73446  217.498108  203.218047  205.888372  196.004509
#
#          2021        2022        2023
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2  206.266945  203.679268   400.47292
# 3         ...         ...         ...
# 4  145.059377  133.350101  137.022421
# 5  101.969696   93.572913   96.982195
# 6         NaN         NaN         NaN
# 7   28.444557    45.59734   34.624312
# 8    7.495921    8.238626    10.26588
# 9  207.353323   184.44945  191.375671
#
# [10 rows x 37 columns]

# %%
# Remove rows where 'Country' is NaN or contains placeholders like "Africa", "North Africa", etc.
# Keep rows where 'Country' is a specific country (e.g., not containing NaN or regional labels)

# Drop rows with any NaN values in the 'Country' column
data_cleaned_3 = data_cleaned_3.dropna(subset=['Country'])

# Remove rows where the data in any year column contains placeholders like '...' and convert values to numeric
data_cleaned_3.replace('...', pd.NA, inplace=True)
data_cleaned_3.iloc[:, 1:] = data_cleaned_3.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# Display the cleaned data to confirm it is ready for analysis
data_cleaned_3.head()
# Out:
#         Country       1988       1989       1990       1991       1992  \
# 0        Africa        NaN        NaN        NaN        NaN        NaN
# 1  North Africa        NaN        NaN        NaN        NaN        NaN
# 2       Algeria  42.429214  34.323059  35.436521  21.623099  39.378707
# 3         Libya        NaN        NaN        NaN        NaN        NaN
# 4       Morocco  38.669076  41.020171  43.535896  45.959889  48.365283
#
#         1993       1994       1995       1996  ...        2014        2015  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2  46.680964  47.782928  43.354702  50.109747  ...  250.886996  263.326354
# 3        NaN        NaN        NaN        NaN  ...  615.882666         NaN
# 4  48.505698  52.104802  54.058374  53.599344  ...  118.211116   94.243465
#
#         2016        2017        2018        2019        2020        2021  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2  253.28049  244.873569  228.581208  241.273869   223.42533  206.266945
# 3        NaN         NaN         NaN         NaN         NaN         NaN
# 4  94.768334   97.429113  102.896263  102.504513  131.673155  145.059377
#
#          2022        2023
# 0         NaN         NaN
# 1         NaN         NaN
# 2  203.679268   400.47292
# 3         NaN         NaN
# 4  133.350101  137.022421
#
# [5 rows x 37 columns]

# %%
# Remove regional aggregates by keeping only rows where 'Country' is a specific country
# Here, we can filter out rows with common regional terms or just focus on rows with substantial numeric data

# Filter to keep only rows with at least some non-null values across the years
data_Per_capita = data_cleaned_3.dropna(thresh=5, axis=0).reset_index(drop=True)

# Display the cleaned data focused on individual countries
data_Per_capita.head()
# Out:
#    Country        1988        1989        1990       1991       1992  \
# 0  Algeria   42.429214   34.323059   35.436521  21.623099  39.378707
# 1    Libya         NaN         NaN         NaN        NaN        NaN
# 2  Morocco   38.669076   41.020171   43.535896  45.959889  48.365283
# 3  Tunisia   28.866073   28.350537   29.366811  30.201905  32.906636
# 4   Angola  132.855604  170.343509  148.038985  84.328055  62.862251
#
#         1993       1994       1995       1996  ...        2014        2015  \
# 0  46.680964  47.782928  43.354702  50.109747  ...  250.886996  263.326354
# 1        NaN        NaN        NaN        NaN  ...  615.882666         NaN
# 2  48.505698  52.104802  54.058374  53.599344  ...  118.211116   94.243465
# 3  30.763856  32.491398  36.895035  42.145002  ...   79.478516   84.729783
# 4  136.09433  44.197829  16.808778  11.106301  ...  252.368376  128.281396
#
#         2016        2017        2018        2019        2020        2021  \
# 0  253.28049  244.873569  228.581208  241.273869   223.42533  206.266945
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2  94.768334   97.429113  102.896263  102.504513  131.673155  145.059377
# 3  84.522908   72.724543   70.747286   83.070971   95.162997  101.969696
# 4   94.80552  101.389418   63.426928   45.463891   29.723418   28.444557
#
#          2022        2023
# 0  203.679268   400.47292
# 1         NaN         NaN
# 2  133.350101  137.022421
# 3   93.572913   96.982195
# 4    45.59734   34.624312
#
# [5 rows x 37 columns]

# %%
# Output the cleaned DataFrame with country-specific military expenditure data to a CSV file
output_path = "Cleaned_SIPRI_Military_Expenditure-Per_Capita.csv"
data_Per_capita.to_csv(output_path, index=False)

output_path
# Out:
# 'Cleaned_SIPRI_Military_Expenditure-Per_Capita.csv'

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 4. Load and Clean 'Share of Govt. spending' Sheet

# %%
# Load sheet
data_Share_Gov = pd.read_excel(file_path, sheet_name="Share of Govt. spending")

# Display the first few rows
data_Share_Gov.head(15)
# Out:
#    Military expenditure by country as percentage of government spending, 1948-2023         © SIPRI 2023  \
# 0       Countries are grouped by region and subregion
# 1   Figures are for miltary expenditure expressed ...
# 2   Data for general government expenditure are fr...
# 3   Figures in blue are SIPRI estimates. Figures i...
# 4   ". ." = data unavailable. "xxx" = country did ...
# 5                                                 NaN
# 6                                             Country
# 7                                                 NaN
# 8                                              Africa
# 9                                        North Africa
# 10                                            Algeria
# 11                                              Libya
# 12                                            Morocco
# 13                                            Tunisia
# 14                                 sub-Saharan Africa
#
#    Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         NaN             NaN        NaN        NaN        NaN        NaN
# 1         NaN             NaN        NaN        NaN        NaN        NaN
# 2         NaN             NaN        NaN        NaN        NaN        NaN
# 3         NaN             NaN        NaN        NaN        NaN        NaN
# 4         NaN             NaN        NaN        NaN        NaN        NaN
# 5         NaN             NaN        NaN        NaN        NaN        NaN
# 6       Notes  Reporting year       1988       1989       1990       1991
# 7         NaN             NaN        NaN        NaN        NaN        NaN
# 8         NaN             NaN        NaN        NaN        NaN        NaN
# 9         NaN             NaN        NaN        NaN        NaN        NaN
# 10          §             NaN        ...        ...   0.057841   0.040441
# 11        ‡§¶             NaN        ...        ...        ...        ...
# 12          §             NaN        ...        ...   0.145002   0.158037
# 13        NaN             NaN        ...        ...        ...   0.063269
# 14        NaN             NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 0         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 5         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 6        1992       1993       1994  ...        2014        2015        2016
# 7         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 8         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 9         NaN        NaN        NaN  ...         NaN         NaN         NaN
# 10   0.069904   0.070861   0.093684  ...    0.134377    0.135656    0.152039
# 11        ...        ...        ...  ...    0.109068         ...         ...
# 12    0.15113   0.158109   0.162983  ...    0.110783    0.104176    0.104448
# 13   0.063291   0.061916   0.064018  ...    0.065263     0.07796     0.08176
# 14        NaN        NaN        NaN  ...         NaN         NaN         NaN
#
#    Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6         2017        2018        2019        2020        2021        2022
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10    0.146409    0.135999    0.143587     0.15694     0.15025    0.126723
# 11         ...         ...         ...         ...         ...         ...
# 12    0.105925    0.104896    0.104736    0.116552    0.120053    0.118359
# 13    0.070733    0.068902    0.080702    0.078555    0.079197    0.070461
# 14         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 38
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6         2023
# 7          NaN
# 8          NaN
# 9          NaN
# 10    0.193357
# 11         ...
# 12     0.11122
# 13    0.070458
# 14         NaN
#
# [15 rows x 39 columns]

# %%
# Reload and skip irrelevant rows to get only the actual data
data_cleaned_4 = pd.read_excel(file_path, sheet_name="Share of Govt. spending", skiprows=7)

# Adjust year column selection to match the integer format in the dataset
year_columns = list(range(1988, 2024))  # Using integers for years
data_cleaned_4 = data_cleaned_4[['Country'] + year_columns]

# Display the cleaned data to verify structure and ensure it matches expectations for analysis
data_cleaned_4.head(10)
# Out:
#               Country 1988      1989      1990      1991      1992      1993  \
# 0                 NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 1              Africa  NaN       NaN       NaN       NaN       NaN       NaN
# 2        North Africa  NaN       NaN       NaN       NaN       NaN       NaN
# 3             Algeria  ...       ...  0.057841  0.040441  0.069904  0.070861
# 4               Libya  ...       ...       ...       ...       ...       ...
# 5             Morocco  ...       ...  0.145002  0.158037   0.15113  0.158109
# 6             Tunisia  ...       ...       ...  0.063269  0.063291  0.061916
# 7  sub-Saharan Africa  NaN       NaN       NaN       NaN       NaN       NaN
# 8              Angola  ...       ...       ...       ...       ...       ...
# 9               Benin  ...  0.104652  0.092393       ...       ...       ...
#
#        1994      1995      1996  ...      2014      2015      2016      2017  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 3  0.093684  0.093543  0.106039  ...  0.134377  0.135656  0.152039  0.146409
# 4       ...       ...       ...  ...  0.109068       ...       ...       ...
# 5  0.162983   0.16004   0.17614  ...  0.110783  0.104176  0.104448  0.105925
# 6  0.064018  0.062582  0.066741  ...  0.065263   0.07796   0.08176  0.070733
# 7       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 8       ...       ...  0.060329  ...  0.128877  0.114798     0.124  0.104141
# 9       ...       ...       ...  ...  0.049276  0.043987  0.043661  0.051763
#
#        2018      2019      2020      2021      2022      2023
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN
# 3  0.135999  0.143587   0.15694   0.15025  0.126723  0.193357
# 4       ...       ...       ...       ...       ...       ...
# 5  0.104896  0.104736  0.116552  0.120053  0.118359   0.11122
# 6  0.068902  0.080702  0.078555  0.079197  0.070461  0.070458
# 7       NaN       NaN       NaN       NaN       NaN       NaN
# 8  0.095039  0.085236  0.074624  0.066798  0.058413  0.055282
# 9  0.038229  0.032416  0.024055  0.027745  0.031821   0.03754
#
# [10 rows x 37 columns]

# %%
# Remove rows where 'Country' is NaN or contains placeholders like "Africa", "North Africa", etc.
# Keep rows where 'Country' is a specific country (e.g., not containing NaN or regional labels)

# Drop rows with any NaN values in the 'Country' column
data_cleaned_4 = data_cleaned_4.dropna(subset=['Country'])

# Remove rows where the data in any year column contains placeholders like '...' and convert values to numeric
data_cleaned_4.replace('...', pd.NA, inplace=True)
data_cleaned_4.iloc[:, 1:] = data_cleaned_4.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# Display the cleaned data to confirm it is ready for analysis
data_cleaned_4.head()
# Out:
#         Country 1988 1989      1990      1991      1992      1993      1994  \
# 1        Africa  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 2  North Africa  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 3       Algeria  NaN  NaN  0.057841  0.040441  0.069904  0.070861  0.093684
# 4         Libya  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 5       Morocco  NaN  NaN  0.145002  0.158037   0.15113  0.158109  0.162983
#
#        1995      1996  ...      2014      2015      2016      2017      2018  \
# 1       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3  0.093543  0.106039  ...  0.134377  0.135656  0.152039  0.146409  0.135999
# 4       NaN       NaN  ...  0.109068       NaN       NaN       NaN       NaN
# 5   0.16004   0.17614  ...  0.110783  0.104176  0.104448  0.105925  0.104896
#
#        2019      2020      2021      2022      2023
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 3  0.143587   0.15694   0.15025  0.126723  0.193357
# 4       NaN       NaN       NaN       NaN       NaN
# 5  0.104736  0.116552  0.120053  0.118359   0.11122
#
# [5 rows x 37 columns]

# %%
# Remove regional aggregates by keeping only rows where 'Country' is a specific country
# Here, we can filter out rows with common regional terms or just focus on rows with substantial numeric data

# Filter to keep only rows with at least some non-null values across the years
data_Share_Gov = data_cleaned_4.dropna(thresh=5, axis=0).reset_index(drop=True)

# Display the cleaned data focused on individual countries
data_Share_Gov.head()
# Out:
#    Country 1988 1989      1990      1991      1992      1993      1994  \
# 0  Algeria  NaN  NaN  0.057841  0.040441  0.069904  0.070861  0.093684
# 1    Libya  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 2  Morocco  NaN  NaN  0.145002  0.158037   0.15113  0.158109  0.162983
# 3  Tunisia  NaN  NaN       NaN  0.063269  0.063291  0.061916  0.064018
# 4   Angola  NaN  NaN       NaN       NaN       NaN       NaN       NaN
#
#        1995      1996  ...      2014      2015      2016      2017      2018  \
# 0  0.093543  0.106039  ...  0.134377  0.135656  0.152039  0.146409  0.135999
# 1       NaN       NaN  ...  0.109068       NaN       NaN       NaN       NaN
# 2   0.16004   0.17614  ...  0.110783  0.104176  0.104448  0.105925  0.104896
# 3  0.062582  0.066741  ...  0.065263   0.07796   0.08176  0.070733  0.068902
# 4       NaN  0.060329  ...  0.128877  0.114798     0.124  0.104141  0.095039
#
#        2019      2020      2021      2022      2023
# 0  0.143587   0.15694   0.15025  0.126723  0.193357
# 1       NaN       NaN       NaN       NaN       NaN
# 2  0.104736  0.116552  0.120053  0.118359   0.11122
# 3  0.080702  0.078555  0.079197  0.070461  0.070458
# 4  0.085236  0.074624  0.066798  0.058413  0.055282
#
# [5 rows x 37 columns]

# %%
# Output the cleaned DataFrame with country-specific military expenditure data to a CSV file
output_path = "Cleaned_SIPRI_Military_Expenditure-Share_of_Govt_spending.csv"
data_Share_Gov.to_csv(output_path, index=False)

output_path
# Out:
# 'Cleaned_SIPRI_Military_Expenditure-Share_of_Govt_spending.csv'
